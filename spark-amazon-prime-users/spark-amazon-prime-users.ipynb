# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# %%capture
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
from pyspark.sql.functions import *

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler

# %% [markdown]
# # Lendo o arquivo csv e transformando em dataframe
# ---

# %%
dados = spark.read.csv('', header=True)

# %% [markdown]
# # Mostrando os 5 primeiros registros do dataframe
# ---

# %%
dados.toPandas().head()
# Out:
#   User ID              Name                   Email Address  \
# 0       1     Ronald Murphy      williamholland@example.com
# 1       2       Scott Allen             scott22@example.org
# 2       3  Jonathan Parrish            brooke16@example.org
# 3       4    Megan Williams         elizabeth31@example.net
# 4       5     Kathryn Brown  pattersonalexandra@example.org
#
#              Username Date of Birth  Gender        Location  \
# 0      williamholland    1953-06-03    Male  Rebeccachester
# 1             scott22    1978-07-08    Male   Mcphersonview
# 2            brooke16    1994-12-06  Female       Youngfort
# 3         elizabeth31    1964-12-22  Female    Feliciashire
# 4  pattersonalexandra    1961-06-04    Male    Port Deborah
#
#   Membership Start Date Membership End Date Subscription Plan  \
# 0            2024-01-15          2025-01-14            Annual
# 1            2024-01-07          2025-01-06           Monthly
# 2            2024-04-13          2025-04-13           Monthly
# 3            2024-01-24          2025-01-23           Monthly
# 4            2024-02-14          2025-02-13            Annual
#
#   Payment Information Renewal Status Usage Frequency Purchase History  \
# 0          Mastercard         Manual         Regular      Electronics
# 1                Visa         Manual         Regular      Electronics
# 2          Mastercard         Manual         Regular            Books
# 3                Amex     Auto-renew         Regular      Electronics
# 4                Visa     Auto-renew        Frequent         Clothing
#
#   Favorite Genres Devices Used Engagement Metrics Feedback/Ratings  \
# 0     Documentary     Smart TV             Medium              3.6
# 1          Horror   Smartphone             Medium              3.8
# 2          Comedy     Smart TV                Low              3.3
# 3     Documentary     Smart TV               High              3.3
# 4           Drama     Smart TV                Low              4.3
#
#   Customer Support Interactions
# 0                             3
# 1                             7
# 2                             8
# 3                             7
# 4                             1

# %% [markdown]
# # Contando a quantidade de registros (linhas) no dataframe
# ---

# %%
f'{dados.count()} linhas'
# Out:
# '2500 linhas'

# %% [markdown]
# # Quantos usuários únicos estão presentes no dataframe?
# ---

# %%
f'{dados.select("User ID").distinct().count()} usuários únicos'
# Out:
# '2500 usuários únicos'

# %% [markdown]
# # Qual o usuário mais velho presente no dataframe?
# > Mais velho é diferente de mais antigo
# ---

# %%
dados.select(min('Date of Birth')).toPandas()
# Out:
#   min(Date of Birth)
# 0         1933-04-26

# %% [markdown]
# # Qual a média do feedback agregada para cada gênero no dataframe?
# ---

# %%
dados.groupby('Gender').agg(
    avg('Feedback/Ratings').alias('feedback_avg')).toPandas()
# Out:
#    Gender  feedback_avg
# 0  Female      4.000968
# 1    Male      4.008492

# %% [markdown]
# # Definindo um novo dataframe que possua apenas os registros que possuem mais do que 3 interações com o suporte de cliente
# ---

# %%
dados_quest_7 = dados.filter(dados['Customer Support Interactions'] > 3)
dados_quest_7.toPandas()
# Out:
#      User ID               Name                  Email Address  \
# 0          2        Scott Allen            scott22@example.org
# 1          3   Jonathan Parrish           brooke16@example.org
# 2          4     Megan Williams        elizabeth31@example.net
# 3          7  Benjamin Marshall       michaellewis@example.net
# 4          8        James Smith         adrienne49@example.org
# ...      ...                ...                            ...
# 1570    2494        Jerry Bruce         virginia02@example.net
# 1571    2495     Jennifer Burch  andersonchristina@example.net
# 1572    2498      Morgan Barnes       erikaholland@example.net
# 1573    2499     Gina Castaneda       reedcourtney@example.net
# 1574    2500     Mark Nicholson        martinisaac@example.net
#
#                Username Date of Birth  Gender             Location  \
# 0               scott22    1978-07-08    Male        Mcphersonview
# 1              brooke16    1994-12-06  Female            Youngfort
# 2           elizabeth31    1964-12-22  Female         Feliciashire
# 3          michaellewis    2003-02-09    Male       Carlsonchester
# 4            adrienne49    1946-10-04    Male  West Matthewborough
# ...                 ...           ...     ...                  ...
# 1570         virginia02    1962-07-03    Male    North Tinaborough
# 1571  andersonchristina    1950-04-18  Female              New Ian
# 1572       erikaholland    1972-03-31  Female     Alexandraborough
# 1573       reedcourtney    1965-08-02  Female         Williammouth
# 1574        martinisaac    1972-11-13  Female       Estradaborough
#
#      Membership Start Date Membership End Date Subscription Plan  \
# 0               2024-01-07          2025-01-06           Monthly
# 1               2024-04-13          2025-04-13           Monthly
# 2               2024-01-24          2025-01-23           Monthly
# 3               2024-04-08          2025-04-08           Monthly
# 4               2024-02-16          2025-02-15           Monthly
# ...                    ...                 ...               ...
# 1570            2024-04-05          2025-04-05            Annual
# 1571            2024-03-06          2025-03-06            Annual
# 1572            2024-02-09          2025-02-08            Annual
# 1573            2024-02-18          2025-02-17           Monthly
# 1574            2024-01-28          2025-01-27            Annual
#
#      Payment Information Renewal Status Usage Frequency Purchase History  \
# 0                   Visa         Manual         Regular      Electronics
# 1             Mastercard         Manual         Regular            Books
# 2                   Amex     Auto-renew         Regular      Electronics
# 3                   Amex     Auto-renew        Frequent         Clothing
# 4                   Visa         Manual         Regular      Electronics
# ...                  ...            ...             ...              ...
# 1570                Visa     Auto-renew         Regular            Books
# 1571          Mastercard     Auto-renew      Occasional         Clothing
# 1572                Visa         Manual        Frequent      Electronics
# 1573                Visa         Manual         Regular         Clothing
# 1574                Visa     Auto-renew         Regular            Books
#
#      Favorite Genres Devices Used Engagement Metrics Feedback/Ratings  \
# 0             Horror   Smartphone             Medium              3.8
# 1             Comedy     Smart TV                Low              3.3
# 2        Documentary     Smart TV               High              3.3
# 3             Sci-Fi       Tablet             Medium              4.4
# 4             Horror     Smart TV             Medium              3.6
# ...              ...          ...                ...              ...
# 1570          Horror     Smart TV               High              5.0
# 1571           Drama   Smartphone             Medium              4.1
# 1572     Documentary       Tablet                Low              4.9
# 1573          Comedy   Smartphone               High              3.4
# 1574     Documentary     Smart TV               High              3.3
#
#      Customer Support Interactions
# 0                                7
# 1                                8
# 2                                7
# 3                               10
# 4                                6
# ...                            ...
# 1570                             4
# 1571                             8
# 1572                             8
# 1573                             7
# 1574                             9
#
# [1575 rows x 19 columns]

# %% [markdown]
# # A partir do dataframe definido anteriormente, definindo outro que possua apenas as colunas `Customer Support Interactions`,  `Feedback/Ratings` e `User ID`
# ---

# %%
dados_quest_8 = dados_quest_7.select(
    'Customer Support Interactions', 'Feedback/Ratings', 'User ID')
dados_quest_8.toPandas()
# Out:
#      Customer Support Interactions Feedback/Ratings User ID
# 0                                7              3.8       2
# 1                                8              3.3       3
# 2                                7              3.3       4
# 3                               10              4.4       7
# 4                                6              3.6       8
# ...                            ...              ...     ...
# 1570                             4              5.0    2494
# 1571                             8              4.1    2495
# 1572                             8              4.9    2498
# 1573                             7              3.4    2499
# 1574                             9              3.3    2500
#
# [1575 rows x 3 columns]

# %% [markdown]
# # A partir do dataframe definido anteriormente, convertendo as colunas `Customer Support Interactions` e `Feedback/Ratings` de string para float
# ---

# %%
dados_quest_8.printSchema()
# Out:
# root
#  |-- Customer Support Interactions: string (nullable = true)
#  |-- Feedback/Ratings: string (nullable = true)
#  |-- User ID: string (nullable = true)

# %%
dados_quest_9 = dados_quest_8 \
    .withColumn('Customer Support Interactions', col('Customer Support Interactions').cast('float')) \
    .withColumn('Feedback/Ratings', col('Feedback/Ratings').cast('float'))

# %%
dados_quest_9.printSchema()
# Out:
# root
#  |-- Customer Support Interactions: float (nullable = true)
#  |-- Feedback/Ratings: float (nullable = true)
#  |-- User ID: string (nullable = true)

# %% [markdown]
# # A partir do dataframe definido anteriormente, aplicando padronização nas colunas `Customer Support Interactions` e `Feedback/Ratings`
# ---

# %%
dados_quest_10 = VectorAssembler(inputCols=['Customer Support Interactions', 'Feedback/Ratings'],
                                 outputCol='features').transform(dados_quest_9)

# %%
scale = StandardScaler(inputCol='features',
                       outputCol='standardized')

# %%
scale = scale.fit(dados_quest_10)

# %%
dados_quest_10 = scale.transform(dados_quest_10)

# %%
dados_quest_10.select('standardized').toPandas()
# Out:
#                                  standardized
# 0      [3.473623924959035, 6.612033834245978]
# 1      [3.9698559142388974, 5.74202937145439]
# 2       [3.473623924959035, 5.74202937145439]
# 3      [4.962319892798622, 7.656039438506157]
# 4      [2.977391935679173, 6.264031966159251]
# ...                                       ...
# 1570  [1.9849279571194487, 8.700044627915881]
# 1571  [3.9698559142388974, 7.134036428950839]
# 1572  [3.9698559142388974, 8.526043901297745]
# 1573   [3.473623924959035, 5.916030512922981]
# 1574    [4.466087903518759, 5.74202937145439]
#
# [1575 rows x 1 columns]
